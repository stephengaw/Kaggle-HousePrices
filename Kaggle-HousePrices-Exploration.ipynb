# %%
# Load the training data

import pandas as pd

file_in = './train.csv'

df = pd.read_csv(file_in)

# %%
# Get numeric values and correlation matrix

dfn = df.select_dtypes(include=['float64', 'int64'])
cols = list(dfn.columns.values)
corr = dfn.corr()
# Out:
# 38

# %%
# Make a better Correlation Matrix Plot
import numpy as np

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111)
cax = ax.matshow(corr)
fig.colorbar(cax)

ax.set_xticklabels(cols)
ax.set_yticklabels(cols)

plt.xticks(np.arange(0, len(cols), 1.0), rotation='vertical')
plt.yticks(np.arange(0, len(cols), 1.0))

plt.show()
